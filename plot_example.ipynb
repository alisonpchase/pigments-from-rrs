# %%
from pigments_from_rss.spectra import calculate_spectra
from pigments_from_rss.plot import plot_spectra

# %%
spectra = calculate_spectra(use_mock_data=True, divisor=1000)

# %%
plot_spectra(spectra=spectra, title="Chase et al. 2017")
